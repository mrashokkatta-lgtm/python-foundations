# %%
# Variables and Data Types

name = "Ashok"
age = 30
is_ml_engineer = True
salary = 85000.50

print("Name:", name)
print("Age:", age)
print("ML Engineer:", is_ml_engineer)
print("Salary:", salary)

print("\nData Types:")
print(type(name))
print(type(age))
print(type(is_ml_engineer))
print(type(salary))
# Out:
# Name: Ashok
# Age: 30
# ML Engineer: True
# Salary: 85000.5
#
# Data Types:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
