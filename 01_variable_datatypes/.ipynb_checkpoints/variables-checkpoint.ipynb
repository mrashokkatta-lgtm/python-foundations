# %%
# Refreshing my Python3 coding skills 
# Variables and Data Types

name = "Ashok Kumar Katta"
age = 40
is_ml_engineer = True
salary = 2400000
aspirations = "Techincal Program Manager"

print("Name:", name)
print("Age:", age)
print("ML Engineer:", is_ml_engineer)
print("Salary:", salary)
print("Aspirations:",aspirations)

print("\nData Types:")
print(type(name))
print(type(age))
print(type(is_ml_engineer))
print(type(salary))
print(type(aspirations))
# Out:
# Name: Ashok
# Age: 30
# ML Engineer: True
# Salary: 85000.5
#
# Data Types:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
